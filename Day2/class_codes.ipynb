# %%
w = 0.5
dw = 1

# %%
lr = 1.0
w_new = w - lr * dw
print(f"Updated weight (w_new): {w_new}")
# Out:
# Updated weight (w_new): -0.5

# %%
p_val = 0.6
actual_val = 1.0

L = (actual_val - p_val) ** 2
