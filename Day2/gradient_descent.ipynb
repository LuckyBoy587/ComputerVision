# %%
w = 0.5
n = 0.1
dw = 0.2

w_new = w - n * dw
print(f"Updated weight (w_new): {w_new}")
# Out:
# Updated weight (w_new): 0.48

# %%
n = 1.0
w_new = w - n * dw
print(f"Updated weight (w_new): {w_new}")
# Out:
# Updated weight (w_new): 0.3
