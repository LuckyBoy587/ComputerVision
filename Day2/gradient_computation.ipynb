# %%
import numpy as np

# %%
y = 1.0
y_hat = 0.6
w = 0.5
x = 2.0

# %%
dl_dy_hat = 2 * (y_hat - y)
dy_hat_dw = x
dl_dw = dl_dy_hat * dy_hat_dw

# %%
print(f"dL/dŷ = {dl_dy_hat:.1f}")
print(f"dŷ/dw = {dy_hat_dw:.0f}")
print(f"dL/dw = {dl_dw:.1f}")
# Out:
# dL/dŷ = -0.8
# dŷ/dw = 2
# dL/dw = -1.6
