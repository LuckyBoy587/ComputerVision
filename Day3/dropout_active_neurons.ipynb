# %%
total_neurons = 6
dropout_rate = 0.5

# %%
def compute_active_neurons(total, rate):
    return total * (1.0 - rate)

# %%
active_neurons = compute_active_neurons(total_neurons, dropout_rate)
print(f"Active neurons after dropout = {active_neurons}")
