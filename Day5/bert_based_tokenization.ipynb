# %%
reviews = [

    "This product performs efficiently and meets expectations",

    "The quality of the item is unsatisfactory",

    "Delivery was completed on time and packaging was secure",

    "The product stopped functioning after a short period",

    "Good value for the price",

    "Not worth the cost considering performance",

    "The product is reliable and functions as described",

    "The build quality is poor and feels fragile",

    "Customer support was responsive and helpful",

    "Battery performance is below expectations",

    "Overall experience with this product is satisfactory",

    "The design and appearance are well executed",

    "The product does not perform as specified",

    "Satisfied with the purchase",

    "Would not recommend this product",

    "Performance is consistent and easy to use",

    "The item arrived damaged and delayed",

    "Functions as expected without major issues",

    "Unsatisfactory experience with the product",

    "Durable and reliable under regular usage"

]

# %%
selected = reviews[:3]

# %%
lower_case_reviews = [review.lower() for review in selected]

# %%
from transformers import BertTokenizer
import torch

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
for i, review in enumerate(lower_case_reviews):
    encoded = tokenizer(
        review,
        add_special_tokens=True,
        max_length=20,
        padding='max_length',
        truncation=True,
        return_tensors='pt'
    )

    input_ids = encoded["input_ids"][0]
    tokens = tokenizer.convert_ids_to_tokens(input_ids)
    attention_mask = encoded["attention_mask"][0]

    print(f"Review {i + 1}: {review}")
    print(f"Tokens: {tokens}")
    print(f"Input IDs: {input_ids.tolist()}")
    print(f"Attention Mask: {attention_mask.tolist()}")
    print()
