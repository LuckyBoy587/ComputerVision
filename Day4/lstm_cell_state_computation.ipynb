# %%
ft = 0.7
it = 0.6
c_candidate = 0.5
c_prev = 1.0

# %%
def compute_lstm_cell_state(f, i, c_cand, c_prev):
    return f * c_prev + i * c_cand

# %%
ct = compute_lstm_cell_state(ft, it, c_candidate, c_prev)
print(f"New cell state C_t = {ct}")
